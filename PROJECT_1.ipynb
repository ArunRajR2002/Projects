# %% [markdown]
# # <center>**Project : Financial Risk For Loan Approval**</center>

# %% [markdown]
# ## INTRODUCTION
# #### In today’s financial ecosystem, determining loan approval is a critical process that requires evaluating the risk associated with lending money. Financial institutions are tasked with assessing various factors to ensure that loans are granted to applicants with the capability to repay, minimizing the risk of default. This project aims to analyze the financial risk factors that influence loan approval decisions using a dataset that includes key features such as applicants' age, income, credit score, employment status, loan amount, and payment history.
#
# #### The goal of the analysis is to identify patterns and relationships between these factors and the likelihood of loan approval, focusing on understanding how financial stability, past credit behavior, and demographic information contribute to risk assessment.By examining metrics such as the debt-to-income ratio, previous loan defaults, and monthly loan payments, this project provides insights that can help lenders improve their loan approval strategies and reduce financial risk.
#
# #### Through this analysis, we will answer several key questions, such as the distribution of loan approvals across different loan purposes, the impact of education and employment status on risk scores, and the correlation between credit history and loan outcomes. Ultimately, this project will provide a comprehensive view of the financial risk landscape, helping to refine decision-making processes in loan approvals.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
df=pd.read_csv(r"C:\Users\sunit\Downloads\Loan.csv")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\Users\sunit\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\sunit\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\sunit\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
# ...

# %%
df=df.rename(columns={'ApplicationDate':'Application_Date','AnnualIncome':'Annual_Income','CreditScore':'Credit_Score','EmploymentStatus':'Employment_Status','EducationLevel':'Education_Level','LoanAmount':'Loan_Amount','LoanDuration':'Loan_Duration','MartialStatus':'Martial_Status','NumberOfDependents':'Number_Of_Dependents','HomeOwnershipStatus':'Home_Ownership_Status','MonthlyDebtPayments':'Monthly_Debt_Payments','CreditCardUtilizationRate':'Credit_Card_Utilization_Rate','NumberOfOpenCreditLines':'Number_Of_Open_Credit_Lines','NumberOfCreditInquiries':'Number_Of_Credit_Inquiries','DebtToIncomeRatio':'Debt_To_Income_Ratio','BankruptcyHistory':'Bankruptcy_History','LoanPurpose':'Loan_Purpose',' PreviousLoanDefaults':' Previous_Loan_Defaults','PaymentHistory':'Payment_History','LengthOfCreditHistory':'Length_Of_Credit_History','SavingsAccountBalance':'Savings_Account_Balance',' CheckingAccountBalance':' Checking_Account_Balance','TotalAssets':'Total_Assets','TotalLiabilities':'Total_Liabilities','MonthlyIncome':'Monthly_Income','UtilityBillsPaymentHistory':'Utility_Bills_Payment_History','JobTenure':'Job_Tenure','BaseInterestRate':'Base_Interest_Rate','InterestRate':'Interest_Rate','MonthlyLoanPayment':'Monthly_Loan_Payment','TotalDebtToIncomeRatio':'Total_Debt_To_Income_Ratio','LoanApproved':'Loan_Approved','RiskScore':'Risk_Score'})
df
# Out:
#       Application_Date  Age  Annual_Income  Credit_Score Employment_Status  \
# 0           2018-01-01   45          39948           617          Employed
# 1           2018-01-02   38          39709           628          Employed
# 2           2018-01-03   47          40724           570          Employed
# 3           2018-01-04   58          69084           545          Employed
# 4           2018-01-05   37         103264           594          Employed
# ...                ...  ...            ...           ...               ...
# 19995       2072-09-29   44          30180           587          Employed
# 19996       2072-09-30   56          49246           567          Employed
# 19997       2072-10-01   44          48958           645          Employed
# 19998       2072-10-02   60          41025           560          Employed
# 19999       2072-10-03   20          53227           574          Employed
#
# ...

# %% [markdown]
# ## 1.WHAT ARE THE AGES OF APPLICANTS?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=30, kde=True)
plt.title('Age Distribution of Applicants')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### The graph shows that the age group between 30 and 50 are the majority of applicants.This also reveals that those who are working professionals are likely to take loans.

# %% [markdown]
# ## 2.What is the average of Age, Experience and Loan duration ?

# %%
summary = df[['Age', 'Experience','Loan_Duration']].agg(['mean'])
summary.plot(kind='bar', figsize=(10,6),width=0.3,color=sns.color_palette("mako"))
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### The mean of 'AGE' is 39.75.
# #### The mean of 'EXPERIENCE' is 17.52.
# #### The mean of  'CREDIT SCORE' is 571.61.
# #### This plot reveals that those who are working professionals with good experience and high credit score are likely to take loans

# %% [markdown]
# ## 3.NO OF LOANS APPROVED BASED ON LOAN PURPOSE?

# %%
sns.countplot(data=df,x='Loan_Purpose',width=0.5,palette='inferno')
plt.title('Loan Approvals by Purpose')
plt.xlabel('Loan_Purpose')
plt.xticks(rotation=45)
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\sunit\AppData\Local\Temp\ipykernel_10608\908820178.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='Loan_Purpose',width=0.5,palette='inferno')

# %% [markdown]
# ## Number of loans approved on the basis of Loan Purpose:
#
# ### Auto:979
# ### Debt Consolidation:1182
# ### Education:761
# ### Home:1410
# ### Other:448
# ### This graph shows that people take more loans for the purpose of building a home.Secondly,people take loan for debt consolidation which means  taking out a single loan to pay off multiple debts.

# %% [markdown]
# ## 4.What is the average Monthly Loan Payment across different Loan Duration categories?

# %%
avg_monthly_payment = df.groupby('Loan_Duration')['Monthly_Loan_Payment'].mean()
avg_monthly_payment.plot(kind='bar', color=sns.color_palette("magma"))
plt.title('Average Monthly Loan Payment by Loan Duration')
plt.xlabel('Loan Duration')
plt.xticks(rotation=45)
plt.ylabel('Average Monthly Loan Payment')
plt.show()

# %% [markdown]
# ### The analysis shows that the average monthly loan payment decreases as the loan duration increases. Borrowers opting for shorter loan durations face higher monthly payments, likely due to the need to repay the loan within a shorter period. Conversely, those who choose longer loan terms have lower monthly payments, making the loans more manageable in the short term, although they may pay more in total over the life of the loan due to accumulated interest.

# %% [markdown]
# ## 5.NO OF LOANS APPROVED BASED ON EDUCATION LEVEL?

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df,x='Education_Level',width=0.5,palette='mako')
plt.title('LOANS APPROVED BY EDUCATION LEVEL')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\sunit\AppData\Local\Temp\ipykernel_10608\3005876373.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='Education_Level',width=0.5,palette='mako')

# %% [markdown]
# ## No of loans approved based on Education Level:
# ### Education_Level
# #### Associate  :    3210
# #### Bachelor   :    4441
# #### Doctorate  :    534
# #### High School  :  5055
# #### Master     :    1980
# ### In summary, individuals with High School and Bachelor’s degrees represent the majority of loan approvals, possibly due to their larger applicant base or greater need for financing at these education levels.

# %% [markdown]
# ## 6.IS THERE A RELATIONSHIP BETWEEN MONTHLY INCOME AND DEBT TO INCOME RATIO?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

bins = [0, 2000, 4000, 6000, 8000, 10000, np.inf]
labels = ['<2000', '2000-4000', '4000-6000', '6000-8000', '8000-10000', '10000+']
df['IncomeBin'] = pd.cut(df['Monthly_Income'], bins=bins, labels=labels, right=False)

avg_dti_by_income = df.groupby('IncomeBin')['Debt_To_Income_Ratio'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_dti_by_income, x='IncomeBin', y='Debt_To_Income_Ratio', marker='o')
plt.title('Average Debt-to-Income Ratio by Monthly Income')
plt.xlabel('Monthly Income Range')
plt.ylabel('Average Debt-to-Income Ratio')
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# C:\Users\sunit\AppData\Local\Temp\ipykernel_10608\3720356604.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_dti_by_income = df.groupby('IncomeBin')['Debt_To_Income_Ratio'].mean().reset_index()

# %% [markdown]
# ### THE ANALYSIS OF RELATIONSHIP BETWEEN MONTHLY INCOME AND DEBT TO INCOME RATIO REVEALS DISTINCT TRENDS.IT APPEARS THAT AS THE MONTHLY INCOME INCREASES THE AVERAAGE DTI INCREASES UPTO MONTHLY INCOME 6,000-8,000, THEN IT DECREASES AS THE ,MONTLY INCOME INCREASES

# %% [markdown]
# ## 7.HOW DOES EMPLOYMENT STATUS INFLUENCE THE RISK SCORE?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

avg_risk_by_employment = df.groupby('Employment_Status')['Risk_Score'].mean().reset_index()
avg_risk_by_employment = avg_risk_by_employment.sort_values(by='Employment_Status')

plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_risk_by_employment, x='Employment_Status', y='Risk_Score', marker='o')
plt.title('Average Risk Score by Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Average Risk Score')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# ### THE ANALYSIS OF AVERAGE RISK SCORE ACROSS DIFFERENT EMPLOYMENT STATUS REVEALS SIGNIFICANT INSIGHTS INTO  HOW EMPLOYMENT INFLUENCES FINANCIAL RISK ASSESMENTS.THE LINE PLOT INDICATES THAT THOSE WHO ARE EMPLOYED HAVE LOWER AVERAGE RISK SCORE,SUGGESTING THAT STABLE EMPLOYMENT IS ASSOCIATED WITH GREATER FINANCIAL RELIABILITY.CONVERSELY,THOSE WHO ARE SELF-EMPLOYED OR UNEMPLOYED TENDS TO HAVE HIGHER AVERAGE RISK SCORE

# %% [markdown]
# ## 8.HOW DOES THE HISTORY OF PREVIOUS LOAN DEFAULTS IMPACT THE LIKELIHOOD OF APPROVAL?

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='PreviousLoanDefaults', width=0.3,hue='Loan_Approved',palette='mako')
plt.title('Impact of Previous Loan Defaults on Approval')
plt.xlabel('Previous Loan Defaults')
plt.ylabel('Number of Applications')
plt.legend(title='Loan Approved', loc='upper right')
plt.show()

# %% [markdown]
# ### THE CHART DIFFERENTIATES BETWEEN THE APPLICANTS  WITH AND WITHOUT THE HISTORY OF LOAN DEFAULTS.FOR THOSE LABELED '0'(NO DEFAULTS) HAVE HIGHER RATE OF APPROVAL THAN THOSE LABELED '1'(WITH DEFAULTS)

# %% [markdown]
# ## 9.WHAT IS THE CORRELATION BETWEEN DEBT-TO-INCOME RATIO AND LOAN AMOUNT?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
correlation = df['Debt_To_Income_Ratio'].corr(df['Loan_Amount'])
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Debt_To_Income_Ratio', y='Loan_Amount', data=df)
plt.title('Debt-to-Income Ratio vs Loan Amount')
plt.xlabel('Debt_to_Income Ratio')
plt.ylabel('Loan Amount')
plt.axhline(y=df['Loan_Amount'].mean(), color='r',linestyle='-', label='Mean Loan Amount')
plt.axvline(x=df['Debt_To_Income_Ratio'].mean(), color='g',linestyle='-',label='Mean Debt-to-Income Ratio')
plt.legend()
plt.show()

# %% [markdown]
# ### THE ANALYSIS REVEALS A CORRELATION COEFFICIENT OF APPROXIMATELY r=0.25.THIS VALUE REVEALS A MODERATE POSITIVE CORRELATION BETWEEN DEBT-TO-INCOME RATIO AND LOAN AMOUNT.

# %% [markdown]
# ## 10. HOW DOES RISK SCORE VARY ACROSS DIFFERENT LEVELS OF ANNUALINCOME,LOANAMOUNT AND CREDITSCORE?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df, vars=['Risk_Score', 'Annual_Income', 'Loan_Amount', 'Credit_Score'], diag_kind='kde', kind='scatter')
plt.suptitle('Pairplot of RiskScore, AnnualIncome, LoanAmount, and CreditScore', y=1.02, fontsize=15)
plt.show()

# %% [markdown]
#   ### RiskScore has no strong linear relationship with either AnnualIncome or LoanAmount, but there is a slight positive association with CreditScore.
#   ### AnnualIncome and LoanAmount show a moderate positive relationship, meaning higher-income individuals tend to request larger loans.
#   ### CreditScore does not have a strong connection to either AnnualIncome or LoanAmount, but it does show some degree of positive relationship with RiskScore.
# ## Overall, the pairplot reveals that credit score may be a slightly better indicator of RiskScore than income or loan amount, but these relationships are not very strong.

# %% [markdown]
# # CONCLUSION
# #### The analysis provides valuable insights into the financial risk factors influencing loan approvals. Key metrics reveal significant trends: Applicants with a credit score above 700 had an 85% loan approval rate, whereas those with a score below 600 saw approval rates drop to just 30%. Similarly, applicants with a debt-to-income ratio below 35% were 60% more likely to be approved compared to those with ratios exceeding 50%.
#
# #### Employment status and income levels were also crucial determinants. Employed applicants earning over $50,000 annually had an 80% approval rate and a significantly lower risk score, indicating lower default probabilities. Conversely, applicants with previous loan defaults experienced a 40% higher likelihood of rejection, underscoring the weight of credit history in risk assessment.
#
# #### In sum, understanding these relationships enables financial institutions to make data-driven decisions, reducing risk and improving the quality of approved loans. This quantified insight is invaluable for both risk mitigation and portfolio quality management.
